# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinthaniManthilaka/BioInformatics-practicals/blob/main/Differential%20Expression%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
