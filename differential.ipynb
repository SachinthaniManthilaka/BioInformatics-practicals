# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinthaniManthilaka/BioInformatics-practicals/blob/main/differential.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c3ba9f1d-d985-4595-b481-03871f42f77b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3ba9f1d-d985-4595-b481-03871f42f77b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("dea_data.csv")

# %%
import numpy as np
import pandas as pd
data=pd.read_csv('dea_data.csv')
data.head()
# Out:
#     Gene  Control1  Control2  Control3  Control4  Control5  Control6  \
# 0  Gene1        56        97        19        76        65        25
# 1  Gene2         8        93        64        18        13        94
# 2  Gene3        64        45        33        19        49        69
# 3  Gene4        94        46        81        55        67        56
# 4  Gene5        63        36        92        56        66        62
#
#    Control7  Control8  Control9  ...  Treatment16  Treatment17  Treatment18  \
# 0        87        91        79  ...           55           59           68
# 1        57         6        88  ...           91           66           44
# 2        93        75        13  ...           82            7            5
# 3         8        98        27  ...           74           76           31
# 4        56        16        43  ...           77           63           74
#
#    Treatment19  Treatment20  Treatment21  Treatment22  Treatment23  \
# ...

# %%
control_cols=[i for i in data.columns if "Control" in i]
data['average control columns']=data[control_cols].mean(axis=1)
print(data[['Gene','average control columns']])
treatment_cols=[i for i in data.columns if "Treatment" in i]
data['average control columns']=data[control_cols].mean(axis=1)
print(data[['Gene','average control columns']])
# Out:
#        Gene  average control columns
# 0     Gene1                    53.52
# 1     Gene2                    47.08
# 2     Gene3                    45.16
# 3     Gene4                    51.44
# 4     Gene5                    48.04
# ..      ...                      ...
# 95   Gene96                    51.56
# 96   Gene97                    49.32
# 97   Gene98                    45.40
# 98   Gene99                    58.08
# 99  Gene100                    51.72
#
# [100 rows x 2 columns]
#        Gene  average control columns
# 0     Gene1                    53.52
# 1     Gene2                    47.08
# 2     Gene3                    45.16
# 3     Gene4                    51.44
# 4     Gene5                    48.04
# ..      ...                      ...
# 95   Gene96                    51.56
# 96   Gene97                    49.32
# 97   Gene98                    45.40
# 98   Gene99                    58.08
# 99  Gene100                    51.72
#
# [100 rows x 2 columns]

# %%
#compute log2 fold change
df['Log2FC']=np.log2(df['Treatment mean']/df['Log2FC'])
